# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame, Index

from pathlib import Path
from datetime import date
import requests

import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
import seaborn as sns

# %% [markdown]
# ***

# %% [markdown]
# # A Dataset about Music Information, collected by Spotify.

# %% [markdown]
# ## Source
# Reference where the data comes from so the analysis can be reproduced by someone else. Provide the URL where to data can be retrieved from or the URL to download a data file.
#
# Source: https://www.kaggle.com/datasets/kauvinlucas/30000-albums-aggregated-review-ratings
#
# The following code retrieves CSV data from links stored in a Web page at Kaggle

# %% [markdown]
# ## Abstract
# In this project, we will be invesigating in the contemporary album rating and reviews in the United States. The purpose of this project is to analyze the dataset and extract insights of pattern of the rating and review system and to perdict which types of music ablums are likely to get highly popularity and rating.In additional analysis aims to answer questions such as: What are the most expensive and affordable State to buy a house in the United States? What factors contribute to the price of a house ? What are the most popular type of houses that are being listed for sale? By answering these questions, this project aims to provide a better understanding of the rating system in general, an

# %% [markdown]
# ***

# %% [markdown]
# ## A brief info about our Dataset
# > __First DataFrame__: The main dataset we will use  <br>
#
# > __Second DataFrame__: This dataFrame contains the __Metacritics Review/Scores__ and excluded AOTY(Album of the year) columns.  <br>
#
# > __Third DataFrame__:This dataFrame contains the __AOTY(Album of the year) Review/Scores__ and excluded from Metatcritcs columns.  <br>

# %%
musicData = pd.read_csv('Group_Project/album_ratings.csv')
musicData
# Out:
#                             Artist                                    Title  \
# 0                        Neko Case                           Middle Cyclone
# 1      Jason Isbell & The 400 Unit              Jason Isbell & The 400 Unit
# 2                Animal Collective               Merriweather Post Pavilion
# 3                Bruce Springsteen                       Working on a Dream
# 4                      Andrew Bird                              Noble Beast
# ...                            ...                                      ...
# 32353           Death Valley Girls                   Under the Spell of Joy
# 32354                     Gorillaz  Song Machine, Season One: Strange Timez
# 32355                 Tobin Sprout                             Empty Horses
# 32356                  Jeremy Ivey                    Waiting out the Storm
# 32357                Delmer Darion                         Morning Pageants
#
# ...

# %%
metaMusic = musicData[['Artist','Title','Release Month','Release Day','Release Year','Format','Label','Genre',
                      'Metacritic Critic Score','Metacritic Reviews','Metacritic User Score','Metacritic User Reviews']]
metaMusic
# Out:
#                             Artist                                    Title  \
# 0                        Neko Case                           Middle Cyclone
# 1      Jason Isbell & The 400 Unit              Jason Isbell & The 400 Unit
# 2                Animal Collective               Merriweather Post Pavilion
# 3                Bruce Springsteen                       Working on a Dream
# 4                      Andrew Bird                              Noble Beast
# ...                            ...                                      ...
# 32353           Death Valley Girls                   Under the Spell of Joy
# 32354                     Gorillaz  Song Machine, Season One: Strange Timez
# 32355                 Tobin Sprout                             Empty Horses
# 32356                  Jeremy Ivey                    Waiting out the Storm
# 32357                Delmer Darion                         Morning Pageants
#
# ...

# %%
metaMusic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32358 entries, 0 to 32357
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Artist                   32358 non-null  object
#  1   Title                    32357 non-null  object
#  2   Release Month            31769 non-null  object
#  3   Release Day              31768 non-null  object
#  4   Release Year             32358 non-null  int64
#  5   Format                   32358 non-null  object
#  6   Label                    28902 non-null  object
#  7   Genre                    24398 non-null  object
#  8   Metacritic Critic Score  13884 non-null  float64
#  9   Metacritic Reviews       13884 non-null  float64
#  10  Metacritic User Score    9099 non-null   float64
#  11  Metacritic User Reviews  10574 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 3.0+ MB

# %%
metaMusic = metaMusic.dropna('Metacritic User Score'=='Nah')
metaMusic
# Out:
# /var/folders/9c/9kcsj4k174b7gwkqmfs81sm80000gn/T/ipykernel_31995/1496555049.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only.
#   metaMusic = metaMusic.dropna('Metacritic User Score'=='Nah')
#                             Artist                        Title Release Month  \
# 0                        Neko Case               Middle Cyclone         March
# 1      Jason Isbell & The 400 Unit  Jason Isbell & The 400 Unit      February
# 2                Animal Collective   Merriweather Post Pavilion       January
# 3                Bruce Springsteen           Working on a Dream       January
# 4                      Andrew Bird                  Noble Beast       January
# ...                            ...                          ...           ...
# 32080                      Squeeze                The Knowledge       October
# 32141                 Shadows Fall            Fire from the Sky           May
# ...

# %%
AOTYData = musicData[['Artist','Title','Release Month','Release Day','Release Year','Format','Label','Genre',
                      'AOTY Critic Score','AOTY Critic Reviews','AOTY User Score','AOTY User Reviews']]
AOTYData
# Out:
#                             Artist                                    Title  \
# 0                        Neko Case                           Middle Cyclone
# 1      Jason Isbell & The 400 Unit              Jason Isbell & The 400 Unit
# 2                Animal Collective               Merriweather Post Pavilion
# 3                Bruce Springsteen                       Working on a Dream
# 4                      Andrew Bird                              Noble Beast
# ...                            ...                                      ...
# 32353           Death Valley Girls                   Under the Spell of Joy
# 32354                     Gorillaz  Song Machine, Season One: Strange Timez
# 32355                 Tobin Sprout                             Empty Horses
# 32356                  Jeremy Ivey                    Waiting out the Storm
# 32357                Delmer Darion                         Morning Pageants
#
# ...

# %%
AOTYData = AOTYData.dropna()
AOTYData
# Out:
#                             Artist                          Title  \
# 0                        Neko Case                 Middle Cyclone
# 1      Jason Isbell & The 400 Unit    Jason Isbell & The 400 Unit
# 2                Animal Collective     Merriweather Post Pavilion
# 3                Bruce Springsteen             Working on a Dream
# 4                      Andrew Bird                    Noble Beast
# ...                            ...                            ...
# 32303                 Seth Lakeman               A Pilgrim's Tale
# 32307                    Corb Lund            Agricultural Tragic
# 32332                    Firewater                The Golden Hour
# 32341           Grant-Lee Phillips  Lightning, Show Us Your Stuff
# 32350                  DevilDriver          Dealing With Demons I
#
#       Release Month Release Day  Release Year Format             Label  \
# 0             March           3          2009     LP             ANTI-
# ...

# %%
metaMusic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7942 entries, 0 to 32332
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Artist                   7942 non-null   object
#  1   Title                    7942 non-null   object
#  2   Release Month            7942 non-null   object
#  3   Release Day              7942 non-null   object
#  4   Release Year             7942 non-null   int64
#  5   Format                   7942 non-null   object
#  6   Label                    7942 non-null   object
#  7   Genre                    7942 non-null   object
#  8   Metacritic Critic Score  7942 non-null   float64
#  9   Metacritic Reviews       7942 non-null   float64
#  10  Metacritic User Score    7942 non-null   float64
#  11  Metacritic User Reviews  7942 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 806.6+ KB

# %%
AOTYData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22036 entries, 0 to 32350
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Artist               22036 non-null  object
#  1   Title                22036 non-null  object
#  2   Release Month        22036 non-null  object
#  3   Release Day          22036 non-null  object
#  4   Release Year         22036 non-null  int64
#  5   Format               22036 non-null  object
#  6   Label                22036 non-null  object
#  7   Genre                22036 non-null  object
#  8   AOTY Critic Score    22036 non-null  int64
#  9   AOTY Critic Reviews  22036 non-null  int64
#  10  AOTY User Score      22036 non-null  int64
#  11  AOTY User Reviews    22036 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 2.2+ MB
